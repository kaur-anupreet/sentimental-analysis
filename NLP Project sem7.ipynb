# %%
#importing libraries
import pandas as pd
import numpy as np
from sklearn import metrics

# %%
#importing dataset
dataset = pd.read_csv('dataset.tsv',delimiter = '\t',header = None)
X = dataset[1]
y = dataset[0]

# %%
dataset.head()
# Out:
#    0                                                  1
# 0  1            The Da Vinci Code book is just awesome.
# 1  1  this was the first clive cussler i've ever rea...
# 2  1                   i liked the Da Vinci Code a lot.
# 3  1                   i liked the Da Vinci Code a lot.
# 4  1  I liked the Da Vinci Code but it ultimatly did...

# %%
dataset.tail()
# Out:
#       0                                                  1
# 6913  0                     Brokeback Mountain was boring.
# 6914  0       So Brokeback Mountain was really depressing.
# 6915  0  As I sit here, watching the MTV Movie Awards, ...
# 6916  0    Ok brokeback mountain is such a horrible movie.
# 6917  0   Oh, and Brokeback Mountain was a terrible movie.

# %%
dataset[0].sum()
# Out:
# 3943

# %%
len(dataset)
# Out:
# 6918

# %%
#stemming
import re
import nltk
#nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
corpus = []
for i in range(0, len(dataset)):
    review = re.sub('[^a-zA-Z]', ' ', X[i])
    review = review.lower()
    review = review.split()
    ps = PorterStemmer()
    review = [ps.stem(word) for word in review if not word in set(stopwords.words('english'))]
    review = ' '.join(review)
    corpus.append(review)

# %%
corpus
# Out:
# ['da vinci code book awesom',
#  'first clive cussler ever read even book like relic da vinci code plausibl',
#  'like da vinci code lot',
#  'like da vinci code lot',
#  'like da vinci code ultimatli seem hold',
#  'even exagger midnight went wal mart buy da vinci code amaz cours',
#  'love da vinci code want someth better differ',
#  'thought da vinci code great kite runner',
#  'da vinci code actual good movi',
#  'thought da vinci code pretti good book',
#  'da vinci code one beauti movi ive ever seen',
#  'da vinci code amaz book get wrong',
#  'turn light radio enjoy da vinci code',
#  'da vinci code realli good',
#  'love da vinci code',
#  'love da vinci code',
#  'night da vinci code beauti mind',
#  'da vinci code awesom book',
#  'thing enjoy da vinci code',
#  'da vinci code slash amaz race',
#  'hey love da vinci code',
#  'also love da vinci code',
#  'realli enjoy da vinci code thought would disappoint book',
#  'like angel demon da vinci code',
#  'da vinci code realli good movi',
#  'yeah da vinci code awesom movi like pretti interest',
#  'realli like da vinci code',
#  'da vinci code amaz',
#  'da vinci code awesom',
#  'da vinci code backtori variou religi histor figur interest time scifi girl heart',
#  'book love da vinci code',
#  'went see da vinci code crazi awesom ian mckellen old gay husband',
#  'peopl say joe like da vinci code hard dan brown love da vinci code well enjoy bridget jone love da vinci code idea appeal take chick lit one arena genr yet explor read da vinci code awesom way da vinci code excel read normal read novel love da vinci code love read da vinci code tell da vinci code awesom book opinion may bit bias love da vinci code soundtrack quit pleas open minded love da vinci code much abl get equal enjoy see side read',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'da vinci code awesom book',
#  'love da vinci code',
#  'love da vinci code',
#  'da vinci code awesom',
#  'oh beauti da vinci code',
#  'love da vinci code',
#  'da vinci code awesom book',
#  'da vinci code awesom book',
#  'miss rip acoust music da vinci code',
#  'person neither hate love da vinci code',
#  'look amazingli fun possibl bit cold tell anyon da vinci code awesom book',
#  'da vinci code cours awesom book figur page',
#  'love da vinci code',
#  'love da vinci code',
#  'serious da vinci code awesom book',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'omg love da vinci code awesom book',
#  'da vinci code awesom book',
#  'da vinci code still one awesomest book ever read',
#  'love da vinci code though',
#  'da vinci code awesom',
#  'love da vinci code',
#  'shit love da vinci code',
#  'da vinci code realli awesom book also got two book dan brown',
#  'da vinci code awesom book finish',
#  'da vinci code awesom',
#  'love da vinci code',
#  'love da vinci code',
#  'love da vinci code',
#  'damn love da vinci code',
#  'da vinci code fuck awesom',
#  'da vinci code awesom',
#  'da vinci code awesom sound probabl half crap fr',
#  'love da vinci code like',
#  'da vinci code awesom',
#  'love da vinci code rais lot theolog question absurd',
#  'da vinci code awesom book',
#  'yeah da vinci code awesom',
#  'da vinci code awesom though',
#  'love da vinci code',
#  'da vinci code awesom book',
#  'aaron mom aaron knew much love da vinci code took tour insid',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'love go see da vinci code probabl next week',
#  'da vinci code awesom',
#  'im sick book right must say da vinci code awesom',
#  'finish read da vinci code awesom book',
#  'da vinci code awesom far',
#  'love da vinci code',
#  'da vinci code awesom',
#  'read angel demon first onto da vinci code far awesom',
#  'da vinci code awesom book',
#  'da vinci code awesom',
#  'read da vinci code awesom angel demon even better wanna read dan brown book',
#  'da vinci code awesom',
#  'oh oh oh love da vinci code',
#  'love da vinci code',
#  'da vinci code awesom',
#  'love da vinci code illustr edit way go',
#  'love da vinci code wait movi',
#  'love da vinci code recent',
#  'love da vinci code',
#  'right also read love da vinci code',
#  'love da vinci code',
#  'love read da vinci code',
#  'love da vinci code',
#  'love da vinci code',
#  'da vinci code look awesom',
#  'finish da vinci code awesom book',
#  'da vinci code pretti awesom like angel demon',
#  'love read da vinci code wait movi come',
#  'love da vinci code',
#  'da vinci code realli awesom book go get',
#  'love da vinci code thought angel demon pretti good right end kind lost bit',
#  'total love da vinci code ca n wait movi',
#  'person love da vinci code great thriller',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom book',
#  'da vinci code awesom book',
#  'da vinci code awesom',
#  'love da vinci code',
#  'love da vinci code interest think thing differ angl',
#  'da vinci code friggin awesom book',
#  'da vinci code amaz page left go',
#  'love undercov da vinci code',
#  'outta three love da vinci code',
#  'oh love book da vinci code',
#  'besid drowin da vinci code way awesom',
#  'da vinci code awesom',
#  'da vinci code awesom alreadi',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love da vinci code',
#  'well da vinci code awesom',
#  'realli love da vinci code',
#  'book da vinci code awesom',
#  'saw da vinci code awesom',
#  'love da vinci code',
#  'know love da vinci code',
#  'da vinci code awesom',
#  'lynn jon theater da vinci code everyon luau awesom',
#  'da vinci code awesom movi',
#  'also da vinci code awesom',
#  'gasp love da vinci code',
#  'movi da vinci code awesom protest make sad know mani peopl share religion idiot',
#  'da vinci code like one awesomest book',
#  'sad may date sister enjoy time togeth absolut love da vinci code',
#  'da vinci code awesom mean jesu admir bachelor',
#  'da vinci code awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'da vinci code one beauti movi',
#  'love da vinci code',
#  'beyond da vinci code beauti tome unauthor cours deal novel inspir',
#  'actual love da vinci code',
#  'saw da vinci code x men last stand day came one got talk x men da vinci code awesom',
#  'love da vinci code',
#  'agre love da vinci code think ridicul peopl get panti bunch heresi blashpemi whatev hell els allegedli contain',
#  'da vinci code awesom lah',
#  'da vinci code awesom',
#  'love watch da vinci code soon',
#  'hard decid move ti see good one play would love see da vinci code hand hedg look funni',
#  'read book angel demon got hook finish two day like da vinci code',
#  'oh love da vinci code',
#  'back melbourn mom went see da vinci code total awesom left thing',
#  'hahash love da vinci code tooo',
#  'da vinci code awesom',
#  'da vinci code also awesom that given tom hank',
#  'love da vinci code',
#  'love da vinci code',
#  'love da vinci code kick ass movi',
#  'went movi saw da vinci code honestli awesom movi ever seen',
#  'love da vinci code even though second book seri',
#  'da vinci code awesom opinion book movi',
#  'love da vinci code book movi',
#  'da vinci code sooo awesom good luck ur tenni tournament',
#  'da vinci code awesom',
#  'love hate america almost much love support da vinci code',
#  'da vinci code awesom',
#  'luv book da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love da vinci code',
#  'well da vinci code awesom',
#  'da vinci code awesom',
#  'da vinci code awesom book finsh read',
#  'da vinci code awesom cannot even begin comprehend explain awesom hardcor awesom power awesom',
#  'ps da vinci code awesom movi',
#  'love da vinci code much',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'peopl worth know much love da vinci code',
#  'want desper love da vinci code film',
#  'da vinci code awesom wait read',
#  'da vinci code absolut awesom',
#  'da vinci code awesom movi',
#  'da vinci code awesom',
#  'love da vinci code',
#  'da vinci code awesom',
#  'da vinci code awesom',
#  'love luv lubb da vinci code',
#  'friday stay watch mission imposs amaz way',
#  'love mission imposs',
#  'mission imposs excit',
#  'ok time updat wow updat long time ok yeah watch hedg mission imposs awesom movi hammi rock',
#  'mission imposs amaz',
#  'first action theme play firework went mission imposs theme good accompani whistl bang colour lit sky',
#  'first action theme play firework went mission imposs theme good accompani whistl bang colour lit sky',
#  'mission imposs good unpredict spi movi like sort thing',
#  'love mission imposs scenario',
#  'mission imposs astonishingli good fat free much worth rent',
#  ...]

# %%
type(X)
# Out:
# pandas.core.series.Series

# %%
type(corpus)
# Out:
# list

# %%
X
# Out:
# 0                 The Da Vinci Code book is just awesome.
# 1       this was the first clive cussler i've ever rea...
# 2                        i liked the Da Vinci Code a lot.
# 3                        i liked the Da Vinci Code a lot.
# 4       I liked the Da Vinci Code but it ultimatly did...
# 5       that's not even an exaggeration ) and at midni...
# 6       I loved the Da Vinci Code, but now I want some...
# 7       i thought da vinci code was great, same with k...
# 8           The Da Vinci Code is actually a good movie...
# 9       I thought the Da Vinci Code was a pretty good ...
# 10      The Da Vinci Code is one of the most beautiful...
# 11      The Da Vinci Code is an * amazing * book, do n...
# 12      then I turn on the light and the radio and enj...
# 13                     The Da Vinci Code was REALLY good.
# 14                               i love da vinci code....
# 15                                i loved da vinci code..
# 16      TO NIGHT:: THE DA VINCI CODE AND A BEAUTIFUL M...
# 17               THE DA VINCI CODE is AN AWESOME BOOK....
# 18                 Thing is, I enjoyed The Da Vinci Code.
# 19                 very da vinci code slash amazing race.
# 20                       Hey I loved The Da Vinci Code!..
# 21                         also loved the da vinci code..
# 22      I really enjoyed the Da Vinci Code but thought...
# 23      I do like Angels and Demons more then The Da V...
# 24             The Da Vinci Code was a really good movie.
# 25      yeah, da vinci code is an awesome movie i like...
# 26                       I really like The Da Vinci Code.
# 27                              Da Vinci Code is amazing.
# 28                       The Da Vinci Code was awesome...
# 29      The Da Vinci Code's backtory on various religi...
#                               ...
# 6888             Brokeback Mountain is fucking horrible..
# 6889    Then snuck into Brokeback Mountain, which is t...
# 6890    , she helped me bobbypin my insanely cool hat ...
# 6891    My dad's being stupid about brokeback mountain...
# 6892    Oh, and Brokeback Mountain is a TERRIBLE movie...
# 6893                       Brokeback Mountain was boring.
# 6894         So Brokeback Mountain was really depressing.
# 6895    As I sit here, watching the MTV Movie Awards, ...
# 6896      Ok brokeback mountain is such a horrible movie.
# 6897     Oh, and Brokeback Mountain was a terrible movie.
# 6898             Brokeback Mountain is fucking horrible..
# 6899    Then snuck into Brokeback Mountain, which is t...
# 6900    , she helped me bobbypin my insanely cool hat ...
# 6901    My dad's being stupid about brokeback mountain...
# 6902    Oh, and Brokeback Mountain is a TERRIBLE movie...
# 6903                       Brokeback Mountain was boring.
# 6904         So Brokeback Mountain was really depressing.
# 6905    As I sit here, watching the MTV Movie Awards, ...
# 6906      Ok brokeback mountain is such a horrible movie.
# 6907     Oh, and Brokeback Mountain was a terrible movie.
# 6908             Brokeback Mountain is fucking horrible..
# 6909    Then snuck into Brokeback Mountain, which is t...
# 6910    , she helped me bobbypin my insanely cool hat ...
# 6911    My dad's being stupid about brokeback mountain...
# 6912    Oh, and Brokeback Mountain is a TERRIBLE movie...
# 6913                       Brokeback Mountain was boring.
# 6914         So Brokeback Mountain was really depressing.
# 6915    As I sit here, watching the MTV Movie Awards, ...
# 6916      Ok brokeback mountain is such a horrible movie.
# 6917     Oh, and Brokeback Mountain was a terrible movie.
# Name: 1, Length: 6918, dtype: object

# %%
# Creating the Bag of Words model
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
X = cv.fit_transform(corpus).toarray()

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)
# Out:
# /Users/gp/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# # Different classifiers - Unigram model

# %%
# Fitting Multinomial Naive Bayes to the Training set
from sklearn.naive_bayes import MultinomialNB
NB = MultinomialNB()
NB.fit(X_train, y_train)
y_pred = NB.predict(X_test)
print('\nNaive Bayes')
print('Accuracy Score: ',metrics.accuracy_score(y_test,y_pred)*100,'%',sep='')
print('Confusion Matrix: ',metrics.confusion_matrix(y_test,y_pred), sep = '\n')
# Out:
# Naive Bayes
# Accuracy Score: 98.5549132948%
# Confusion Matrix:
# [[597  10]
#  [ 10 767]]

# %%
# Fitting SVM classifier to the Training set
from sklearn.svm import LinearSVC
SVM = LinearSVC()
SVM.fit(X_train, y_train)
y_pred = SVM.predict(X_test)
print('\nSupport Vector Machine')
print('Accuracy Score: ',metrics.accuracy_score(y_test,y_pred)*100,'%',sep='')
print('Confusion Matrix: ',metrics.confusion_matrix(y_test,y_pred), sep = '\n')
# Out:
# Support Vector Machine
# Accuracy Score: 99.4942196532%
# Confusion Matrix:
# [[603   4]
#  [  3 774]]

# %%
# Fitting K Nearest Neighbor classifier to the Training set
from sklearn.neighbors import KNeighborsClassifier
KNN = KNeighborsClassifier(n_neighbors = 3)
KNN.fit(X_train, y_train)
y_pred = KNN.predict(X_test)
print('\nK Nearest Neighbors')
print('Accuracy Score: ',metrics.accuracy_score(y_test,y_pred)*100,'%',sep='')
print('Confusion Matrix: ',metrics.confusion_matrix(y_test,y_pred), sep = '\n')
# Out:
# K Nearest Neighbors
# Accuracy Score: 97.9046242775%
# Confusion Matrix:
# [[586  21]
#  [  8 769]]

# %%
# Fitting Logistic Regression model to the Training set
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression()
LR.fit(X_train, y_train)
y_pred = LR.predict(X_test)
print(X_test.shape)
print('\nLogistic Regression')
print('Accuracy Score: ',metrics.accuracy_score(y_test,y_pred)*100,'%',sep='')
print('Confusion Matrix: ',metrics.confusion_matrix(y_test,y_pred), sep = '\n')
# Out:
# (1384, 1707)
#
# Logistic Regression
# Accuracy Score: 99.6387283237%
# Confusion Matrix:
# [[602   5]
#  [  0 777]]

# %%
# Fitting Random Forest Classifier to the Training set
from sklearn.ensemble import RandomForestClassifier
RF = RandomForestClassifier(n_estimators = 50, criterion = 'entropy', random_state = 0)
RF.fit(X_train, y_train)
y_pred = RF.predict(X_test)
print('\nRandom Forest')
print('Accuracy Score: ',metrics.accuracy_score(y_test,y_pred)*100,'%',sep='')
print('Confusion Matrix: ',metrics.confusion_matrix(y_test,y_pred), sep = '\n')
# Out:
# Random Forest
# Accuracy Score: 98.7716763006%
# Confusion Matrix:
# [[595  12]
#  [  5 772]]

# %%
#Input Review
print('\nTest a custom review message')
print('Enter review to be analysed: ', end=" ")
test = []
test.append(input())
test_dtm = cv.transform(test)
predLabel = LR.predict(test_dtm)
tags = ['Negative','Positive']
#Display Output
print('The review is predicted',tags[predLabel[0]])
# Out:
# Test a custom review message
# Enter review to be analysed:  awesome book
# The review is predicted Positive

# %% [markdown]
# # BIGRAMS

# %%
# Creating the Bag of Words model
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(ngram_range = (2,2))
X = cv.fit_transform(corpus).toarray()

# Splitting the dataset into the Training set and Test set
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %%
# Fitting Multinomial Naive Bayes to the Training set
from sklearn.naive_bayes import MultinomialNB
NB = MultinomialNB()
NB.fit(X_train, y_train)
y_pred = NB.predict(X_test)
print('\nNaive Bayes')
print('Accuracy Score: ',metrics.accuracy_score(y_test,y_pred)*100,'%',sep='')
print('Confusion Matrix: ',metrics.confusion_matrix(y_test,y_pred), sep = '\n')

# %%
# Fitting SVM classifier to the Training set
from sklearn.svm import LinearSVC
SVM = LinearSVC()
SVM.fit(X_train, y_train)
y_pred = SVM.predict(X_test)
print('\nSupport Vector Machine')
print('Accuracy Score: ',metrics.accuracy_score(y_test,y_pred)*100,'%',sep='')
print('Confusion Matrix: ',metrics.confusion_matrix(y_test,y_pred), sep = '\n')

# %%
# Fitting K Nearest Neighbor classifier to the Training set
from sklearn.neighbors import KNeighborsClassifier
KNN = KNeighborsClassifier(n_neighbors = 3)
KNN.fit(X_train, y_train)
y_pred = KNN.predict(X_test)
print('\nK Nearest Neighbors')
print('Accuracy Score: ',metrics.accuracy_score(y_test,y_pred)*100,'%',sep='')
print('Confusion Matrix: ',metrics.confusion_matrix(y_test,y_pred), sep = '\n')

# %%
# Fitting Logistic Regression model to the Training set
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression()
LR.fit(X_train, y_train)
y_pred = LR.predict(X_test)
print('\nLogistic Regression')
print('Accuracy Score: ',metrics.accuracy_score(y_test,y_pred)*100,'%',sep='')
print('Confusion Matrix: ',metrics.confusion_matrix(y_test,y_pred), sep = '\n')

# %%
# Fitting Random Forest Classifier to the Training set
from sklearn.ensemble import RandomForestClassifier
RF = RandomForestClassifier(n_estimators = 15, criterion = 'entropy', random_state = 0)
RF.fit(X_train, y_train)
y_pred = RF.predict(X_test)
print('\nRandom Forest')
print('Accuracy Score: ',metrics.accuracy_score(y_test,y_pred)*100,'%',sep='')
print('Confusion Matrix: ',metrics.confusion_matrix(y_test,y_pred), sep = '\n')

# %% [markdown]
# # TRIGRAMS

# %%
# Creating the Bag of Words model
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_df = .85, max_features = 1500, ngram_range = (3,3))
X = cv.fit_transform(corpus).toarray()

# Splitting the dataset into the Training set and Test set
from sklearn.cross_validation import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 0)

# %%
# Fitting Multinomial Naive Bayes to the Training set
from sklearn.naive_bayes import MultinomialNB
NB = MultinomialNB()
NB.fit(X_train, y_train)
y_pred = NB.predict(X_test)
print('\nNaive Bayes')
print('Accuracy Score: ',metrics.accuracy_score(y_test,y_pred)*100,'%',sep='')
print('Confusion Matrix: ',metrics.confusion_matrix(y_test,y_pred), sep = '\n')

# %%
# Fitting SVM classifier to the Training set
from sklearn.svm import LinearSVC
SVM = LinearSVC()
SVM.fit(X_train, y_train)
y_pred = SVM.predict(X_test)
print('\nSupport Vector Machine')
print('Accuracy Score: ',metrics.accuracy_score(y_test,y_pred)*100,'%',sep='')
print('Confusion Matrix: ',metrics.confusion_matrix(y_test,y_pred), sep = '\n')

# %%
# Fitting K Nearest Neighbor classifier to the Training set
from sklearn.neighbors import KNeighborsClassifier
KNN = KNeighborsClassifier(n_neighbors = 3)
KNN.fit(X_train, y_train)
y_pred = KNN.predict(X_test)
print('\nK Nearest Neighbors')
print('Accuracy Score: ',metrics.accuracy_score(y_test,y_pred)*100,'%',sep='')
print('Confusion Matrix: ',metrics.confusion_matrix(y_test,y_pred), sep = '\n')

# %%
# Fitting Logistic Regression model to the Training set
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression()
LR.fit(X_train, y_train)
y_pred = LR.predict(X_test)
print('\nLogistic Regression')
print('Accuracy Score: ',metrics.accuracy_score(y_test,y_pred)*100,'%',sep='')
print('Confusion Matrix: ',metrics.confusion_matrix(y_test,y_pred), sep = '\n')

# %%
# Fitting Random Forest Classifier to the Training set
from sklearn.ensemble import RandomForestClassifier
RF = RandomForestClassifier(n_estimators = 15, criterion = 'entropy', random_state = 0)
RF.fit(X_train, y_train)
y_pred = RF.predict(X_test)
print('\nRandom Forest')
print('Accuracy Score: ',metrics.accuracy_score(y_test,y_pred)*100,'%',sep='')
print('Confusion Matrix: ',metrics.confusion_matrix(y_test,y_pred), sep = '\n')

# %%
from IPython.display import Image
Image(filename='accuracy.png')

# %% [markdown]
# # Hyperparameters

# %%
"""from sklearn.model_selection import GridSearchCV
parameters = [{'max_df': [1, 0.95, 0.9, 0.85]}]
grid_search = GridSearchCV(estimator = LR,
                           param_grid = parameters,
                           scoring = 'accuracy',
                           cv = 10,
                           n_jobs = -1)
grid_search = grid_search.fit(X, y)
best_accuracy = grid_search.best_score_
best_parameters = grid_search.best_params_"""

# %%
from sklearn.model_selection import GridSearchCV
parameters = {'max_df':(1,0.9,0.8), 'min_df':[0.1,0.2,0.3]}
grid_search = GridSearchCV(estimator = LR,
                           param_grid = parameters,
                           scoring = 'accuracy',
                           cv = 10,
                           )

# %%
grid_search.fit(X_train, y_train)

# %%
grid_search.fit(X_train, y_train).best_params_

# %%
# Creating the Bag of Words model
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_df = .9)
X = cv.fit_transform(corpus).toarray()

# Fitting Logistic Regression model to the Training set
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression()
LR.fit(X_train, y_train)
y_pred = LR.predict(X_test)
print('\nLogistic Regression')
print('Accuracy Score: ',metrics.accuracy_score(y_test,y_pred)*100,'%',sep='')
print('Confusion Matrix: ',metrics.confusion_matrix(y_test,y_pred), sep = '\n')

# %%
# Creating the Bag of Words model
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_df = .8)
X = cv.fit_transform(corpus).toarray()

# Fitting Logistic Regression model to the Training set
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression()
LR.fit(X_train, y_train)
y_pred = LR.predict(X_test)
print('\nLogistic Regression')
print('Accuracy Score: ',metrics.accuracy_score(y_test,y_pred)*100,'%',sep='')
print('Confusion Matrix: ',metrics.confusion_matrix(y_test,y_pred), sep = '\n')

# %%
# Creating the Bag of Words model
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_df = .7)
X = cv.fit_transform(corpus).toarray()

# Fitting Logistic Regression model to the Training set
from sklearn.linear_model import LogisticRegression
LR = LogisticRegression()
LR.fit(X_train, y_train)
y_pred = LR.predict(X_test)
print('\nLogistic Regression')
print('Accuracy Score: ',metrics.accuracy_score(y_test,y_pred)*100,'%',sep='')
print('Confusion Matrix: ',metrics.confusion_matrix(y_test,y_pred), sep = '\n')
